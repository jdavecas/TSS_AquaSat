# %% [markdown]
# #Google Earth Engine (GEE) Python API Colab Setup##
# The code will be writen in GEE python API

# %% [markdown]
# Import the API

# %%
import ee

# %% [markdown]
# Authenticate and initialize

# %%
# Trigger the authentication flow.
#ee.Authenticate()

# Initialize the library.
ee.Initialize()

# %% [markdown]
# # **TSS IN INLAND WATERS**
# Using Aquasat matchups dataset, we want to obtain some methodology to retrieve TSS relationship in inland waters

# %% [markdown]
# #####Import libraries

# %%
#!pip install geemap
import numpy as np
import pandas as pd
import geemap
